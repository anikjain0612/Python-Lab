# %% [markdown]
# #Experiment No. 14
# ##Name: Anik Jain
# ##PRN: 25070123178
# ##Batch: A-3
# ##Title: Data Normalization and Data Type Conversion

# %% [markdown]
# ### Data Normalization

# %%
# Data set
import pandas as pd
import numpy as np
data = {
    'Product':['Laptop','Mobile','Tablet','Headphones','Smartwatch','Camera'],
    'Price':[55000,20000,30000,2000,8000,45000],
    'Units_Sold':[25,60,35,80,50,15],
    'Discount':[10,15,12,20,18,8]
}
df = pd.DataFrame(data)
df
# Out:
#       Product  Price  Units_Sold  Discount
# 0      Laptop  55000          25        10
# 1      Mobile  20000          60        15
# 2      Tablet  30000          35        12
# 3  Headphones   2000          80        20
# 4  Smartwatch   8000          50        18
# 5      Camera  45000          15         8

# %%
# Min-Max Normalization
# Min-Max Normalization for Price
df['Price_MinMax'] = (df['Price'] - df['Price'].min()) / (df['Price'].max() - df['Price'].min()) #Learn formula
df
# Out:
#       Product  Price  Units_Sold  Discount  Price_MinMax
# 0      Laptop  55000          25        10      1.000000
# 1      Mobile  20000          60        15      0.339623
# 2      Tablet  30000          35        12      0.528302
# 3  Headphones   2000          80        20      0.000000
# 4  Smartwatch   8000          50        18      0.113208
# 5      Camera  45000          15         8      0.811321

# %%
df['Units_Sold_MinMax'] = (df['Units_Sold'] - df['Units_Sold'].min()) / (df['Units_Sold'].max() - df['Units_Sold'].min())
df
# Out:
#       Product  Price  Units_Sold  Discount  Price_MinMax  Units_Sold_MinMax
# 0      Laptop  55000          25        10      1.000000           0.153846
# 1      Mobile  20000          60        15      0.339623           0.692308
# 2      Tablet  30000          35        12      0.528302           0.307692
# 3  Headphones   2000          80        20      0.000000           1.000000
# 4  Smartwatch   8000          50        18      0.113208           0.538462
# 5      Camera  45000          15         8      0.811321           0.000000

# %%
#Normalize multiple columns
cols = ['Price','Units_Sold','Discount']
df_norm = (df[cols] - df[cols].min()) / (df[cols].max() - df[cols].min())
df_norm
# Out:
#       Price  Units_Sold  Discount
# 0  1.000000    0.153846  0.166667
# 1  0.339623    0.692308  0.583333
# 2  0.528302    0.307692  0.333333
# 3  0.000000    1.000000  1.000000
# 4  0.113208    0.538462  0.833333
# 5  0.811321    0.000000  0.000000

# %%
# Z-Score Normalization (Standardization)
df['Price_ZScore'] = (df['Price'] - df['Price'].mean()) / df['Price'].std()
df
# Out:
#       Product  Price  Units_Sold  Discount  Price_MinMax  Units_Sold_MinMax  \
# 0      Laptop  55000          25        10      1.000000           0.153846
# 1      Mobile  20000          60        15      0.339623           0.692308
# 2      Tablet  30000          35        12      0.528302           0.307692
# 3  Headphones   2000          80        20      0.000000           1.000000
# 4  Smartwatch   8000          50        18      0.113208           0.538462
# 5      Camera  45000          15         8      0.811321           0.000000
#
#    Price_ZScore
# 0      1.365931
# 1     -0.321396
# 2      0.160698
# 3     -1.189164
# 4     -0.899908
# 5      0.883838

# %%
# Decimal Scaling
df['Price_Decimal'] = df['Price'] / 100000
df
# Out:
#       Product  Price  Units_Sold  Discount  Price_MinMax  Units_Sold_MinMax  \
# 0      Laptop  55000          25        10      1.000000           0.153846
# 1      Mobile  20000          60        15      0.339623           0.692308
# 2      Tablet  30000          35        12      0.528302           0.307692
# 3  Headphones   2000          80        20      0.000000           1.000000
# 4  Smartwatch   8000          50        18      0.113208           0.538462
# 5      Camera  45000          15         8      0.811321           0.000000
#
#    Price_ZScore  Price_Decimal
# 0      1.365931           0.55
# 1     -0.321396           0.20
# 2      0.160698           0.30
# 3     -1.189164           0.02
# 4     -0.899908           0.08
# 5      0.883838           0.45

# %% [markdown]
# ### Standardization

# %%
data1 = {
    'Order_ID':[101,102,103,104,105,106],
    'Customer_Gender':['Male','Female','Female','Male','Female','Male'],
    'Payment_Method':['UPI','Credit Card','Debit Card','COD','UPI','Debit Card'],
    'City':['Pune','Delhi','Mumbai','Chennai','Surat','Chandigarh'],
    'Product_Category':['Electroncs','Clothing','Home','Electronics','Beauty','Home'],
    'Order_Value':[4500,2300,3200,5200,1800,4100]
}
df = pd.DataFrame(data1)
df
# Out:
#    Order_ID Customer_Gender Payment_Method        City Product_Category  \
# 0       101            Male            UPI        Pune       Electroncs
# 1       102          Female    Credit Card       Delhi         Clothing
# 2       103          Female     Debit Card      Mumbai             Home
# 3       104            Male            COD     Chennai      Electronics
# 4       105          Female            UPI       Surat           Beauty
# 5       106            Male     Debit Card  Chandigarh             Home
#
#    Order_Value
# 0         4500
# 1         2300
# 2         3200
# 3         5200
# 4         1800
# 5         4100

# %%
# Label Encoding
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender_Label'] = le.fit_transform(df['Customer_Gender'])
df
# Out:
#    Order_ID Customer_Gender Payment_Method        City Product_Category  \
# 0       101            Male            UPI        Pune       Electroncs
# 1       102          Female    Credit Card       Delhi         Clothing
# 2       103          Female     Debit Card      Mumbai             Home
# 3       104            Male            COD     Chennai      Electronics
# 4       105          Female            UPI       Surat           Beauty
# 5       106            Male     Debit Card  Chandigarh             Home
#
#    Order_Value  Gender_Label
# 0         4500             1
# 1         2300             0
# 2         3200             0
# 3         5200             1
# 4         1800             0
# 5         4100             1

# %%
# One-Hot Encoding
df_encoded = pd.get_dummies(df, columns=['Payment_Method'])
df_encoded
# Out:
#    Order_ID Customer_Gender        City Product_Category  Order_Value  \
# 0       101            Male        Pune       Electroncs         4500
# 1       102          Female       Delhi         Clothing         2300
# 2       103          Female      Mumbai             Home         3200
# 3       104            Male     Chennai      Electronics         5200
# 4       105          Female       Surat           Beauty         1800
# 5       106            Male  Chandigarh             Home         4100
#
#    Gender_Label  Payment_Method_COD  Payment_Method_Credit Card  \
# 0             1               False                       False
# 1             0               False                        True
# 2             0               False                       False
# 3             1                True                       False
# 4             0               False                       False
# 5             1               False                       False
#
# ...

# %%
# Dummy Encoding
df_dummy = pd.get_dummies(df, columns=['Payment_Method'], drop_first=True)
df_dummy
# Out:
#    Order_ID Customer_Gender        City Product_Category  Order_Value  \
# 0       101            Male        Pune       Electroncs         4500
# 1       102          Female       Delhi         Clothing         2300
# 2       103          Female      Mumbai             Home         3200
# 3       104            Male     Chennai      Electronics         5200
# 4       105          Female       Surat           Beauty         1800
# 5       106            Male  Chandigarh             Home         4100
#
#    Gender_Label  Payment_Method_Credit Card  Payment_Method_Debit Card  \
# 0             1                       False                      False
# 1             0                        True                      False
# 2             0                       False                       True
# 3             1                       False                      False
# 4             0                       False                      False
# ...

# %% [markdown]
# # New

# %%
df = pd.read_csv('/content/amazon_products_dataset_Expt-14.csv')

# %%
# MinMax Normalization
'''df['Price_MinMax'] = (df['Price'] - df['Price'].min()) / (df['Price'].max())
df['Units_Sold_MinMax'] = (df['Units_Sold'] - df['Units_Sold'].min())/(df['Units_Sold'].max())'''
cols = ['Price','Units_Sold','Reviews']
df_norm = (df[cols] - df[cols].min()) / (df[cols].max() - df[cols].min())
df_norm
# Out:
#        Price  Units_Sold   Reviews
# 0   0.020243    0.518519  0.291005
# 1   0.048583    0.277778  0.148148
# 2   0.016194    0.203704  0.119048
# 3   0.089069    0.629630  0.444444
# 4   0.149798    0.833333  0.695767
# 5   0.036437    0.592593  0.351852
# 6   0.024291    0.129630  0.052910
# 7   0.064777    0.351852  0.185185
# 8   0.210526    0.481481  0.378307
# 9   0.028340    0.222222  0.089947
# 10  0.311741    1.000000  1.000000
# 11  0.174089    0.407407  0.444444
# 12  0.052632    0.500000  0.232804
# 13  0.016194    0.092593  0.031746
# 14  0.024291    0.240741  0.119048
# 15  0.251012    0.444444  0.497354
# 16  0.036437    0.259259  0.089947
# 17  0.068826    0.648148  0.312169
# 18  0.109312    0.851852  0.814815
# 19  0.040486    0.351852  0.148148
# 20  0.008097    0.148148  0.000000
# 21  0.089069    0.444444  0.272487
# 22  0.352227    0.185185  0.219577
# 23  0.020243    0.259259  0.079365
# 24  0.129555    0.592593  0.444444
# 25  0.174089    0.166667  0.148148
# ...

# %%
# Zscore
df['Price_ZScore'] = (df['Price'] - df['Price'].mean()) / df['Price'].std()
df
# Out:
#    Product_ID                 Product_Name  Price  Rating  Reviews  \
# 0        P101               Wireless Mouse    799     4.3     1520
# 1        P102            Bluetooth Speaker   1499     4.5      980
# 2        P103                 USB Keyboard    699     4.1      870
# 3        P104               Gaming Headset   2499     4.6     2100
# 4        P105                   Smartwatch   3999     4.4     3050
# 5        P106                   Power Bank   1199     4.2     1750
# 6        P107                 Laptop Stand    899     4.0      620
# 7        P108                       Webcam   1899     4.3     1120
# 8        P109                 Portable SSD   5499     4.7     1850
# 9        P110             Wireless Charger    999     4.2      760
# 10       P111  Noise Cancelling Headphones   7999     4.6     4200
# 11       P112          Mechanical Keyboard   4599     4.5     2100
# 12       P113                 Gaming Mouse   1599     4.4     1300
# ...

# %%
# Decimal Scaling
df['Price_Decimal'] = df['Price'] / 10000
df['Reviews_Decimal'] = df['Reviews']/10000
df
# Out:
#    Product_ID                 Product_Name  Price  Rating  Reviews  \
# 0        P101               Wireless Mouse    799     4.3     1520
# 1        P102            Bluetooth Speaker   1499     4.5      980
# 2        P103                 USB Keyboard    699     4.1      870
# 3        P104               Gaming Headset   2499     4.6     2100
# 4        P105                   Smartwatch   3999     4.4     3050
# 5        P106                   Power Bank   1199     4.2     1750
# 6        P107                 Laptop Stand    899     4.0      620
# 7        P108                       Webcam   1899     4.3     1120
# 8        P109                 Portable SSD   5499     4.7     1850
# 9        P110             Wireless Charger    999     4.2      760
# 10       P111  Noise Cancelling Headphones   7999     4.6     4200
# 11       P112          Mechanical Keyboard   4599     4.5     2100
# 12       P113                 Gaming Mouse   1599     4.4     1300
# ...

# %%
# Turning Categorical variables into quantitative variables
df = pd.read_csv('/content/Student-Dataset.csv')
df
# Out:
#    Roll_No  Gender  Department  CGPA  Number_of_Backlogs  \
# 0      101  Female    Computer   8.2                   0
# 1      102    Male          IT   7.5                   1
# 2      103  Female        ENTC   9.1                   0
# 3      104    Male  Mechanical   6.8                   2
# 4      105  Female    Computer   8.7                   0
# 5      106    Male       Civil   7.2                   3
# 6      107  Female          IT   8.9                   0
# 7      108    Male    Computer   6.5                   1
# 8      109  Female        ENTC   7.8                   0
# 9      110    Male  Mechanical   7.0                   2
#
#    Attendance_Percentage Placement_Status  Salary
# 0                     92           Placed  450000
# 1                     85       Not Placed       0
# 2                     96           Placed  550000
# 3                     78       Not Placed       0
# 4                     88           Placed  480000
# ...

# %%
# Label encoding-placement stats
df['Placement_Label'] = le.fit_transform(df['Placement_Status'])
df
# Out:
#    Roll_No  Gender  Department  CGPA  Number_of_Backlogs  \
# 0      101  Female    Computer   8.2                   0
# 1      102    Male          IT   7.5                   1
# 2      103  Female        ENTC   9.1                   0
# 3      104    Male  Mechanical   6.8                   2
# 4      105  Female    Computer   8.7                   0
# 5      106    Male       Civil   7.2                   3
# 6      107  Female          IT   8.9                   0
# 7      108    Male    Computer   6.5                   1
# 8      109  Female        ENTC   7.8                   0
# 9      110    Male  Mechanical   7.0                   2
#
#    Attendance_Percentage Placement_Status  Salary  Placement_Label
# 0                     92           Placed  450000                1
# 1                     85       Not Placed       0                0
# 2                     96           Placed  550000                1
# 3                     78       Not Placed       0                0
# ...

# %%
# One-Hot Encoding - Department
df_encoded = pd.get_dummies(df, columns=['Department'])
df_encoded
# Out:
#    Roll_No  Gender  CGPA  Number_of_Backlogs  Attendance_Percentage  \
# 0      101  Female   8.2                   0                     92
# 1      102    Male   7.5                   1                     85
# 2      103  Female   9.1                   0                     96
# 3      104    Male   6.8                   2                     78
# 4      105  Female   8.7                   0                     88
# 5      106    Male   7.2                   3                     72
# 6      107  Female   8.9                   0                     91
# 7      108    Male   6.5                   1                     80
# 8      109  Female   7.8                   0                     84
# 9      110    Male   7.0                   2                     76
#
#   Placement_Status  Salary  Placement_Label  Department_Civil  \
# 0           Placed  450000                1             False
# 1       Not Placed       0                0             False
# ...

# %%
# Dummy encoding - Department
df_dummy = pd.get_dummies(df, columns=['Department'], drop_first=True)
df_dummy
# Out:
#    Roll_No  Gender  CGPA  Number_of_Backlogs  Attendance_Percentage  \
# 0      101  Female   8.2                   0                     92
# 1      102    Male   7.5                   1                     85
# 2      103  Female   9.1                   0                     96
# 3      104    Male   6.8                   2                     78
# 4      105  Female   8.7                   0                     88
# 5      106    Male   7.2                   3                     72
# 6      107  Female   8.9                   0                     91
# 7      108    Male   6.5                   1                     80
# 8      109  Female   7.8                   0                     84
# 9      110    Male   7.0                   2                     76
#
#   Placement_Status  Salary  Placement_Label  Department_Computer  \
# 0           Placed  450000                1                 True
# 1       Not Placed       0                0                False
# ...
